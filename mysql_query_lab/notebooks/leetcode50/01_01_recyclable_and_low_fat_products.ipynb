# %%
# %run helper/setup_notebook.ipynb import display_table
# Out:
# Successfully connected to leetcode50 database.

# %%
display_table('Products')
# Out:
# +------------+----------+------------+
# | product_id | low_fats | recyclable |
# +------------+----------+------------+
# |     0      |    Y     |     N      |
# |     1      |    Y     |     Y      |
# |     2      |    N     |     Y      |
# |     3      |    Y     |     Y      |
# |     4      |    N     |     N      |
# +------------+----------+------------+

# %% [markdown]
# ### Write an SQL query to find the ids of products that are both low fat and recyclable.
#
# ```
# Output:
# +-------------+
# | product_id  |
# +-------------+
# | 1           |
# | 3           |
# +-------------+
# ```

# %%
# %%sql
#
# SELECT product_id
# FROM products
# WHERE low_fats = 'Y' and recyclable = 'Y';
# Out:
# [(1,), (3,)]

# %% [markdown]
# # Using Pandas

# %%
# remove the Pylance warning for usage of % in python by adding # type: ignore
query = %sql SELECT * FROM products # type: ignore
df = query.DataFrame()
df
# Out:
#    product_id low_fats recyclable
# 0           0        Y          N
# 1           1        Y          Y
# 2           2        N          Y
# 3           3        Y          Y
# 4           4        N          N

# %% [markdown]
# ## ***filter()***

# %%
df.filter(items=['product_id'])
# Out:
#    product_id
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4

# %%
df.filter(items=['product_id']).loc[(df['low_fats'] == 'Y') & (df['recyclable'] == 'Y')]
# Out:
#    product_id
# 1           1
# 3           3

# %% [markdown]
# ## ***loc[]***

# %%
df[df['low_fats'] == 'Y']
# Out:
#    product_id low_fats recyclable
# 0           0        Y          N
# 1           1        Y          Y
# 3           3        Y          Y

# %%
df[(df['low_fats'] == 'Y') & (df['recyclable'] == 'Y')]
# Out:
#    product_id low_fats recyclable
# 1           1        Y          Y
# 3           3        Y          Y

# %%
df[(df['low_fats'] == 'Y') & (df['recyclable'] == 'Y')].product_id
# Out:
# 1    1
# 3    3
# Name: product_id, dtype: int64

# %%
df[(df['low_fats'] == 'Y') & (df['recyclable'] == 'Y')][['product_id']]
# Out:
#    product_id
# 1           1
# 3           3

# %% [markdown]
# ## ***query()***

# %%
df.query("low_fats == 'Y' and recyclable == 'Y' ")
# Out:
#    product_id low_fats recyclable
# 1           1        Y          Y
# 3           3        Y          Y

# %%
df.query("low_fats == 'Y' and recyclable == 'Y'")[['product_id']]
# Out:
#    product_id
# 1           1
# 3           3

# %% [markdown]
# ### Remove index to match the output of the MySQL query.

# %%
# drop index
df.query("low_fats == 'Y' and recyclable == 'Y'")[['product_id']]\
    .set_index('product_id', drop=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 3]

# %% [markdown]
# # Test Results

# %%
output = df.query("low_fats == 'Y' and recyclable == 'Y'")[['product_id']]

# %%
from mysql_query_lab.tests.test_products import test_output
test_output(output, df)
# Out:
# Test passed: Output matches the expected result.

# %% [markdown]
# # Test Results using Button widget

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# Define the output widget
widget_output = widgets.Output()

# Define the function to run the tests
def run_tests(*args):
    """Runs the tests for the `products` module."""
    with widget_output:
        clear_output()
        try:
            test_output(output, df)
        except AssertionError as e:
            print(f"Test failed: {e}")
       
# Define the button and link it to the run_tests function
button = widgets.Button(description="Run Unit Tests")
button.on_click(callback=run_tests)

# Display the button and output widget
display(button, widget_output)
# Out:
# Button(description='Run Unit Tests', style=ButtonStyle())
# Output()

# %% [markdown]
# ![widget](../../assets/widget.png)
