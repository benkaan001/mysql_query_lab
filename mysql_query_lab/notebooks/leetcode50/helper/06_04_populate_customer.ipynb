# %%
# %run setup_notebook.ipynb
# Out:
# Successfully connected to leetcode50 database.

# %%
# %sql -f ../../../../mysql_query_lab/databases/leetcode50_db/06_subqueries/04_restaurant_growth.sql
# Out:
# []
